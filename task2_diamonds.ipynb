# %% [markdown]
# # Task 2 - Guided Diamonds Project
# Author: [Adrian Vega](https://github.com/adriacv17) <br >Respository: [datafun-06-projects](https://github.com/adriacv17/datafun-06-projects) <br> Data: 09/28/2023

# %% [markdown]
# ## Section 1-Load: Get the file, store it in your repo, and load it into a DataFrame.

# %%
import pandas as pd # import pandas library
import numpy as np # import numpy library

diamondsdf = pd.read_csv('diamonds.csv', index_col=0) # Create a DataFrame from csv file

# renaming other columns with small changes for better understanding measures
diamondsdf.columns = ['carat', 'cut', 'color', 'clarity', 'depth(%)', 'table(%)', 'price(USD)', 'X(mm)', 'Y(mm)', 'Z(mm)'] 

diamondsdf # call DataFrame
# Out:
#        carat        cut color clarity  depth(%)  table(%)  price(USD)  X(mm)  \
# 1       0.23      Ideal     E     SI2      61.5      55.0         326   3.95
# 2       0.21    Premium     E     SI1      59.8      61.0         326   3.89
# 3       0.23       Good     E     VS1      56.9      65.0         327   4.05
# 4       0.29    Premium     I     VS2      62.4      58.0         334   4.20
# 5       0.31       Good     J     SI2      63.3      58.0         335   4.34
# ...      ...        ...   ...     ...       ...       ...         ...    ...
# 53936   0.72      Ideal     D     SI1      60.8      57.0        2757   5.75
# 53937   0.72       Good     D     SI1      63.1      55.0        2757   5.69
# 53938   0.70  Very Good     D     SI1      62.8      60.0        2757   5.66
# 53939   0.86    Premium     H     SI2      61.0      58.0        2757   6.15
# 53940   0.75      Ideal     D     SI2      62.2      55.0        2757   5.83
#
#        Y(mm)  Z(mm)
# 1       3.98   2.43
# ...

# %% [markdown]
# ## Section 2-View: Display the first 7 rows and the last 7 rows.

# %%
diamondsdf.head(7) #display first 7 rows
# Out:
#    carat        cut color clarity  depth(%)  table(%)  price(USD)  X(mm)  \
# 1   0.23      Ideal     E     SI2      61.5      55.0         326   3.95
# 2   0.21    Premium     E     SI1      59.8      61.0         326   3.89
# 3   0.23       Good     E     VS1      56.9      65.0         327   4.05
# 4   0.29    Premium     I     VS2      62.4      58.0         334   4.20
# 5   0.31       Good     J     SI2      63.3      58.0         335   4.34
# 6   0.24  Very Good     J    VVS2      62.8      57.0         336   3.94
# 7   0.24  Very Good     I    VVS1      62.3      57.0         336   3.95
#
#    Y(mm)  Z(mm)
# 1   3.98   2.43
# 2   3.84   2.31
# 3   4.07   2.31
# 4   4.23   2.63
# 5   4.35   2.75
# 6   3.96   2.48
# 7   3.98   2.47

# %%
diamondsdf.tail(7) #display last 7 rows
# Out:
#        carat        cut color clarity  depth(%)  table(%)  price(USD)  X(mm)  \
# 53934   0.70  Very Good     E     VS2      61.2      59.0        2757   5.69
# 53935   0.72    Premium     D     SI1      62.7      59.0        2757   5.69
# 53936   0.72      Ideal     D     SI1      60.8      57.0        2757   5.75
# 53937   0.72       Good     D     SI1      63.1      55.0        2757   5.69
# 53938   0.70  Very Good     D     SI1      62.8      60.0        2757   5.66
# 53939   0.86    Premium     H     SI2      61.0      58.0        2757   6.15
# 53940   0.75      Ideal     D     SI2      62.2      55.0        2757   5.83
#
#        Y(mm)  Z(mm)
# 53934   5.72   3.49
# 53935   5.73   3.58
# 53936   5.76   3.50
# 53937   5.75   3.61
# 53938   5.68   3.56
# 53939   6.12   3.74
# 53940   5.87   3.64

# %% [markdown]
# ## Section 3-Describe: Use the DataFrame describe() function to calculate basic descriptive statistics for all numeric columns.

# %%
pd.set_option('display.precision', 2) # format for floating-point values

diamondsdf.describe() # get basic descriptive statistics using describe() funtion using default numeric columns
# Out:
#           carat  depth(%)  table(%)  price(USD)     X(mm)     Y(mm)     Z(mm)
# count  53940.00  53940.00  53940.00    53940.00  53940.00  53940.00  53940.00
# mean       0.80     61.75     57.46     3932.80      5.73      5.73      3.54
# std        0.47      1.43      2.23     3989.44      1.12      1.14      0.71
# min        0.20     43.00     43.00      326.00      0.00      0.00      0.00
# 25%        0.40     61.00     56.00      950.00      4.71      4.72      2.91
# 50%        0.70     61.80     57.00     2401.00      5.70      5.71      3.53
# 75%        1.04     62.50     59.00     5324.25      6.54      6.54      4.04
# max        5.01     79.00     95.00    18823.00     10.74     58.90     31.80

# %% [markdown]
# ## Section 4-Series: Use the Series method describe() to calculate the descriptive stats for all category/text columns.

# %%
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.describe.html for help with library

diamondsdf.describe(exclude=[np.number]) #Excluding numeric columns from a DataFrame description.
# Out:
#           cut  color clarity
# count   53940  53940   53940
# unique      5      7       8
# top     Ideal      G     SI1
# freq    21551  11292   13065

# %% [markdown]
# ## Section 5-Unique: Use the Series method unique() to get unique category values.

# %%
unique_cut = diamondsdf['cut'].unique() #Quality in increasing order Fair, Good, Very Good, Premium, Ideal
print(unique_cut)
# Out:
# ['Ideal' 'Premium' 'Good' 'Very Good' 'Fair']

# %%
unique_clarity = diamondsdf['clarity'].unique() #How obvious inclusions are within the diamond:(in order from best to worst, FL = flawless, I3= level 3 inclusions) FL,IF, VVS1,
print(unique_clarity)
# Out:
# ['SI2' 'SI1' 'VS1' 'VS2' 'VVS2' 'VVS1' 'I1' 'IF']

# %%
unique_color = diamondsdf['color'].unique() #Color of the diamond, with D being the best and J the worst
print(unique_color)
# Out:
# ['E' 'I' 'J' 'H' 'F' 'G' 'D']

# %% [markdown]
# ## Section 6-Histograms: Use the DataFrame's hist() function to create a histogram for each numerical column.

# %%
import matplotlib.pyplot as plt

#enable Matplotlib support
# %matplotlib inline

columns = ['carat', 'depth(%)', 'table(%)', 'price(USD)', 'X(mm)', 'Y(mm)', 'Z(mm)'] # make list of columns for loop

for col in columns: #loop through each column making a histogram
    histogram = diamondsdf.hist(col) # Produce histogram
    
    plt.title(f'Histogram of {col.capitalize()}') # set title
    plt.ylabel('Frequency') #label Y axis
    plt.xlabel(col.capitalize()) #label X axis
